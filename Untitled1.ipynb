# %%
from __future__ import print_function
import pyzbar.pyzbar as pyzbar
import numpy as np
import cv2

# %%
def decode(im) :
    decodedObjects = pyzbar.decode(im)
    # Find barcodes and QR codes
    for obj in decodedObjects:
        print('Type : ', obj.type)
        print('Data : ', str(obj.data),'\n')
        
    return decodedObjects

# %%
# Display barcode and QR code location
def display(im, decodedObjects):
    # Loop over all decoded objects
    for decodedObject in decodedObjects:
        points = decodedObject.polygon
        # If the points do not form a quad, find convex hull
        if len(points) > 4 :
            hull = cv2.convexHull(np.array([point for point in points], dtype=np.float32))
            hull = list(map(tuple, np.squeeze(hull)))
        else :
            hull = points;
        
        # Number of points in the convex hull
        n = len(hull)
        # Draw the convext hull
        for j in range(0,n):
            cv2.line(im, hull[j], hull[ (j+1) % n], (255,0,0), 3)
            
        
    # Display results
    cv2.imshow("Results", im)
    cv2.waitKey(0)

# %%
im=cv2.imread("qr.jpg")
decodedObjects=decode(im)
# Out:
# Type :  QRCODE
# Data :  b'<?xml version="1.0" encoding="UTF-8"?>\n<PrintLetterBarcodeData uid="508027524394" name="SOURAV MAITI" gender="M" yob="1997" gname="MUKTARAM MAITI" house="." street="." loc="Dakshin kalapunja" vtc="Dakshin Kalapunja" po="Naya" dist="Paschim Medinipur" subdist="Pingla" state="West Bengal" pc="721140" dob="25/06/1997"/>'

# %%
decodedObjects
# Out:
# [Decoded(data=b'<?xml version="1.0" encoding="UTF-8"?>\n<PrintLetterBarcodeData uid="508027524394" name="SOURAV MAITI" gender="M" yob="1997" gname="MUKTARAM MAITI" house="." street="." loc="Dakshin kalapunja" vtc="Dakshin Kalapunja" po="Naya" dist="Paschim Medinipur" subdist="Pingla" state="West Bengal" pc="721140" dob="25/06/1997"/>', type='QRCODE', rect=Rect(left=700, top=300, width=223, height=223), polygon=[Point(x=700, y=300), Point(x=701, y=523), Point(x=923, y=523), Point(x=923, y=300)])]

# %%
for obj in decodedObjects:
    points = obj.rect
x1 = points.left
y1 = points.top
x2 = points.left+points.width
y2 = points.top+points.height
cv2.rectangle(im, (x1,y1), (x2,y2), (255,255,255), 2)
#cv2.imshow("result",im)
print(x1,y1,x2,y2)
# Out:
# 700 300 923 523

# %%
# Out:
# list

# %%
cap = cv2.VideoCapture(0)

count=0
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    decodedObjects=decode(frame)
    print(decodedObjects)
    for obj in decodedObjects:
        points = obj.rect
        x1 = points.left
        y1 = points.top
        x2 = points.left+points.width
        y2 = points.top+points.height
        cv2.rectangle(frame, (x1,y1), (x2,y2), (255,255,255), 2)
        
        path="images/"+"qr"+"_" + str(count) + ".jpg"
        cv2.imwrite(path, frame[y1:y2,x1:x2])
        cv2.imshow('image', frame)
        count += 1
            
        
    # Display results
    cv2.imshow("Results", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    elif count >= 10: # Take 30 face sample and stop video
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
import cv2
import numpy as np
import pyzbar.pyzbar as pyzbar
import xml.etree.ElementTree as ET

cap = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_PLAIN
flag=None
while True:
    _, frame = cap.read()

    decodedObjects = pyzbar.decode(frame)
    for obj in decodedObjects:
        data=obj.data
        flag=obj.type
        #cv2.putText(frame, str(obj.data), (50, 50), font, 2, (255, 0, 0), 3)
        (x,y,w,h)=obj.rect
        cv2.rectangle(frame,(x,y),(x+w,y+h), (255,0,0), 2)
    cv2.imshow("Frame", frame)
 
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    elif (flag=='QRCODE'):
        break
        
cap.release()
cv2.destroyAllWindows()
myroot=ET.fromstring(data)
print(myroot.attrib)
# Out:
# {'uid': '508027524394', 'name': 'SOURAV MAITI', 'gender': 'M', 'yob': '1997', 'gname': 'MUKTARAM MAITI', 'house': '.', 'street': '.', 'loc': 'Dakshin kalapunja', 'vtc': 'Dakshin Kalapunja', 'po': 'Naya', 'dist': 'Paschim Medinipur', 'subdist': 'Pingla', 'state': 'West Bengal', 'pc': '721140', 'dob': '25/06/1997'}

# %%
q={}
q['a']='A'
q['b']='B'
list(q.values())
# Out:
# ['A', 'B']

# %%
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont

pdfmetrics.registerFont(TTFont('Roboto Bold', 'Roboto-Bold.ttf'))
pdfmetrics.registerFont(TTFont('Roboto Regular', 'Roboto-Regular.ttf'))

# %%
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import portrait, inch
from reportlab.lib.pagesizes import A4
from reportlab.platypus import Image

def exportPdf():
    c = canvas.Canvas('hello.pdf',pagesize=portrait(A4))
    
    c.setFont('Roboto Regular',20,leading=None)
    c.setFillColorRGB(0.2,0.286,0.376)
    c.drawString(50,750,"Company Name")
    
    c.setFillColorRGB(0.4,0.4,0.4)
    c.setFont('Roboto Regular',10,leading=None)
    c.drawString(52,736,"Address")
    c.drawString(52,724,"Zip code")
    c.drawString(52,712,"Phone Number")
    
    c.setFillColorRGB(0.96,0.40,0.14)
    c.setFont('Roboto Regular',34,leading=None)
    c.drawString(50,660,"Employee Details")
    
    c.setFont('Roboto Bold',16,leading=None)
    c.setFillColorRGB(0.2,0.286,0.376)
    c.drawString(50,620,"EMPLOYEE ID: ")
    
    c.setFillColorRGB(0,0,0)
    c.setFont('Roboto Regular',12,leading=None)
    c.drawString(52,600,"Employee Name: ")
    c.drawString(52,585,"Email ID: ")
    c.drawString(52,570,"Phone Number: ")
    
    c.setFont('Roboto Bold',16,leading=None)
    c.setFillColorRGB(0.2,0.286,0.376)
    c.drawString(50,540,"AADHAAR CARD DETAILS")
    
    c.setFont('Roboto Regular',12,leading=None)
    c.setFillColorRGB(0,0,0)
    c.drawString(52,520,"UID: ")
    c.drawString(52,505,"Name: ")
    c.drawString(52,490,"Gender: ")
    c.drawString(52,475,"YOB: ")
    c.drawString(52,460,"Guardian's Name: ")
    c.drawString(52,445,"House: ")
    c.drawString(52,430,"Street: ")
    c.drawString(52,415,"Location: ")
    c.drawString(52,400,"VTC: ")
    c.drawString(52,385,"P.O.: ")
    c.drawString(52,370,"District: ")
    c.drawString(52,355,"Subdistrict: ")
    c.drawString(52,340,"State: ")
    c.drawString(52,325,"Pin Code: ")
    c.drawString(52,310,"Date of birth: ")
    
    c.drawImage('images/190917021829333009_0.jpg', 400, 510,width=2*inch,height=2*inch)
    
    c.showPage()
    c.save()

# %%
c = canvas.Canvas('hello.pdf',pagesize=portrait(A4))
    
c.setFont('Helvetica',20,leading=None)
c.setFillColorRGB(0.2,0.286,0.376)
c.drawString(50,750,"Company Name")
    
c.setFillColorRGB(0.4,0.4,0.4)
c.setFont('Helvetica',10,leading=None)
c.drawString(52,736,"Address")
c.drawString(52,724,"Zip code")
c.drawString(52,712,"Phone Number")
    
c.setFillColorRGB(0.96,0.40,0.14)
c.setFont('Helvetica-Bold',34,leading=None)
c.drawString(50,660,"Employee Details")
    
c.setFont('Helvetica-Bold',16,leading=None)
c.setFillColorRGB(0.2,0.286,0.376)
c.drawString(50,620,"EMPLOYEE ID: ")
    
c.setFillColorRGB(0,0,0)
c.setFont('Helvetica',12,leading=None)
c.drawString(52,600,"Employee Name: ")
c.drawString(52,585,"Email ID: ")
c.drawString(52,570,"Phone Number: ")
    
c.setFont('Helvetica-Bold',16,leading=None)
c.setFillColorRGB(0.2,0.286,0.376)
c.drawString(50,540,"PERSONAL DETAILS")
    
c.setFont('Helvetica',12,leading=None)
c.setFillColorRGB(0,0,0)
c.drawString(52,520,"UID: ")
c.drawString(52,505,"Name: ")
c.drawString(52,490,"Gender: ")
c.drawString(52,475,"YOB: ")
c.drawString(52,460,"Guardian's Name: ")
c.drawString(52,445,"House: ")
c.drawString(52,430,"Street: ")
c.drawString(52,415,"Location: ")
c.drawString(52,400,"VTC: ")
c.drawString(52,385,"P.O.: ")
c.drawString(52,370,"District: ")
c.drawString(52,355,"Subdistrict: ")
c.drawString(52,340,"State: ")
c.drawString(52,325,"Pin Code: ")
c.drawString(52,310,"Date of birth: ")
    
c.drawImage('images/190917021829333009_0.jpg', 400, 510,width=2*inch,height=2*inch)

date_time=datetime.datetime.now().isoformat()
c.setFont('Helvetica',12,leading=None)
c.setFillColorRGB(0.2,0.286,0.376)
c.drawString(400,480,"Date of joining: "+date_time[:10])
c.drawString(400,465,"Time: "+date_time[11:19])
    
c.showPage()
c.save()

# %%
import datetime
datetime.datetime.now().isoformat()
# Out:
# '2019-09-21T22:15:12.985292'

# %%
c.getAvailableFonts()
# Out:
# ['Courier',
#  'Courier-Bold',
#  'Courier-BoldOblique',
#  'Courier-Oblique',
#  'Helvetica',
#  'Helvetica-Bold',
#  'Helvetica-BoldOblique',
#  'Helvetica-Oblique',
#  'Symbol',
#  'Times-Bold',
#  'Times-BoldItalic',
#  'Times-Italic',
#  'Times-Roman',
#  'ZapfDingbats']

# %%
import boto3
import pickle
s3 = boto3.client('s3')
myList=[1,2,3,4,5]
#Serialize the object 
serializedListObject = pickle.dumps(myList)
#Write to Bucket named 'mytestbucket' and 
#Store the list using key myList001
s3.put_object(Bucket='maitibucket',Key='myList001',Body=serializedListObject)
# Out:
# {'ResponseMetadata': {'RequestId': '9C63B8EAD13AC7C3',
#   'HostId': 'l7/jtYhYxftDhx6NDQdP5kkb9WQVjgi0Mt9rSaE7tLPUxpIyBZDgv1s2eT5diLiWJr5Z4IUCKQE=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'l7/jtYhYxftDhx6NDQdP5kkb9WQVjgi0Mt9rSaE7tLPUxpIyBZDgv1s2eT5diLiWJr5Z4IUCKQE=',
#    'x-amz-request-id': '9C63B8EAD13AC7C3',
#    'date': 'Mon, 23 Sep 2019 16:30:49 GMT',
#    'etag': '"d6a221568fa8202ea0389d42f4522eb6"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 1},
#  'ETag': '"d6a221568fa8202ea0389d42f4522eb6"'}

# %%
myList.append(6)

# %%
serializedListObject = pickle.dumps(myList)
#Write to Bucket named 'mytestbucket' and 
#Store the list using key myList001
s3.put_object(Bucket='maitibucket',Key='myList001',Body=serializedListObject)
# Out:
# {'ResponseMetadata': {'RequestId': '50973A3B55C7DC2B',
#   'HostId': 'lIC1EmSlAi8WqSJkmA0KbJmzuYLKa43tJoSlhH6G5BOU0iGQVhmagrQOCt+elHJWYylHFO2BWrM=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'lIC1EmSlAi8WqSJkmA0KbJmzuYLKa43tJoSlhH6G5BOU0iGQVhmagrQOCt+elHJWYylHFO2BWrM=',
#    'x-amz-request-id': '50973A3B55C7DC2B',
#    'date': 'Mon, 23 Sep 2019 16:34:01 GMT',
#    'etag': '"5395b5ffea88dba8de217c557487d986"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"5395b5ffea88dba8de217c557487d986"'}
